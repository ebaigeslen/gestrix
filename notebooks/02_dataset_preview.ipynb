# %% [markdown]
# # 02_dataset_preview
# Quick smoke-check of PDDL minis and integrity.

# %%
from pathlib import Path

mini = Path("data/processed/mini")
files = sorted([p for p in mini.glob("*.pddl")])
print("Mini problems:", len(files))
for p in files:
    print(" -", p.name)

# %%
# !python scripts/verify_dataset_integrity.py
# !python scripts/check_pddl_syntax.py
